# %%
import pandas as pd
import numpy as np
df = pd.read_csv('MDACC_complete_rpkm_tables.csv')
df.head()
# Out:
#   gene_short_name  17-00225-7_S15Aligned_cufflinks  \
# 0         5S_rRNA                         0.000000
# 1             7SK                         0.000000
# 2            A1BG                         2.070500
# 3        A1BG-AS1                         0.776493
# 4            A1CF                         0.000000
#
#    17-00283-0_S6Aligned_cufflinks  17-00163-6_S7Aligned_cufflinks  \
# 0                        0.000000                         0.00000
# 1                        0.099559                         0.00000
# 2                        3.930820                         3.50732
# 3                        0.558288                         1.33126
# 4                        0.000000                         0.00000
#
#    17-00160-1_S2Aligned_cufflinks  17-00166-3_S11Aligned_cufflinks  \
# 0                         0.00000                         0.000000
# 1                         0.00000                         0.000000
# ...

# %%
sc = pd.read_fwf('tnbc_lean_ipynb.csv')
sc
# Out:
#                                          #############             Unnamed: 1  \
# 0                      ## 101 gene centroid model tool                    NaN
# 1    ## if there are problems contact Brian Ring  b...                    NaN
# 2                                     ## April 26 2017                    NaN
# 3                                        #############                    NaN
# 4                                                  NaN                    NaN
# 5                                                  NaN                    NaN
# 6    #####-----------------------------------------...                    NaN
# 7                                                  NaN                    NaN
# 8                           ## Center the data or not?                    NaN
# 9                                       centerflag="Y"                    NaN
# 10                                     #centerflag="N"                    NaN
# ...

# %%
# !Rscript tnbc_lean_withoptions.R
