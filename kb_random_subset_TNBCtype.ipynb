# %%
import pandas as pd
import numpy as np

my_file = "master_ref_set.csv" 
df = pd.read_csv(my_file)

# Create index and sample dataframes
index_df = df.drop(df.columns[2:], axis=1) 
sample_df = df.drop(df.columns[0:2], axis=1)

# Perform random pick on samples only
random_df = sample_df.sample(n=10, axis=1)

res_df = pd.concat([index_df,random_df], axis=1)
res_df.head()
#res_df.to_csv('random.csv', index=True)
# Out:
#   gene_short_name  V515-06187-A1    TNT-83  17-00118-2_S5Aligned_cufflinks  \
# 0           ABCA8       1.073970   5.23671                        24.40920
# 1          ADRA2A       0.196819   0.04842                         3.19406
# 2          AKAP12       3.752430  10.15370                        14.05680
# 3         ALDH3B2      34.613000  11.95520                         3.29726
# 4            APOD     101.548000  45.57600                       185.23300
#
#       TNT-157   TNT-328  17-00099-0_S15_cufflinks     TNT-274     TNT-133  \
# 0   16.531600   9.23817                   2.37642     1.87787   75.796900
# 1    0.053575   0.00000                   1.09600     0.00000    0.598187
# 2    5.011570   9.39584                   3.23311     2.28224    6.895230
# 3   44.346300  14.56200                  15.29870     4.41511   15.452600
# 4  388.876000  32.46820                   3.69936  1713.18000  152.924000
#
#    17-00269-8_S12Aligned_cufflinks    TNT-154     TNT-13
# 0                        10.575400   0.085644   26.68400
# 1                         0.231559   0.019269    0.00000
# 2                         3.770410   2.750830   11.31620
# 3                         3.695380   2.171180    8.65127
# 4                        55.152100  28.488300  194.97200
